# %% [markdown]
# Applies recurscive feature elimination using Random forest itteratively and saves the feature list with which it achives the best accuracy. On each itteration it eliminates the bottom 5

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import mean
from pyspark.ml.feature import VectorAssembler 
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.feature import VectorAssembler
from pyspark.mllib.evaluation import MulticlassMetrics
import os
import pandas as pd
# Out:
# c:\Anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
spark = SparkSession.builder \
    .appName("LocalFeatureSelection") \
    .config("spark.driver.memory", "55g") \
    .config("spark.executor.memory", "55g") \
    .config("spark.driver.cores", "8") \
    .config("spark.executor.cores", "8") \
    .master("local[8]") \
    .getOrCreate()

# %%
directory = r"C:\Users\hcymm3\Desktop\Dementia"

# %%
dfs = []

# Loop through the files bestfeaturesRF_1.csv to bestfeaturesRF_20.csv
for i in range(1, 21):

    file_name = f"bestfeaturesRF_{i}.csv"
    file_path = os.path.join(directory, file_name)


    df = pd.read_csv(file_path)
    dfs.append(df)

# %%
final_df = pd.concat(dfs, axis=1)

# %%
output_file = os.path.join(directory, "combined_bestfeaturesRF.csv")
final_df.to_csv(output_file, index=False)

# %%
final_df.shape
# Out:
# (534, 2001)

# %%
input_file = r"C:\Users\hcymm3\Desktop\Dementia\combined_bestfeaturesRF.csv"

# %%
df = spark.read.csv(input_file, header=True, inferSchema=True)

# %%
num_rows = df.count()
num_columns = len(df.columns)


print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 534
# Number of columns: 2001

# %%
target_column = df.columns[0]
categorical_columns = df.columns[1:]

# %%
assembler = VectorAssembler(inputCols=categorical_columns, outputCol="features")
assembled_df = assembler.transform(df).select("features", target_column)

# %%
train_df, test_df = assembled_df.randomSplit([0.7, 0.3], seed=42)

# %%
# Set target column and list of features
target_column = df.columns[0]
initial_features = df.columns[1:]

# %%
# Define feature elimination function with step size and accuracy tracking
def rfecv_with_step_size_and_metrics(df, target_column, initial_features, num_iterations, step_size=1):
    remaining_features = initial_features
    best_features = remaining_features
    best_accuracy = 0.0
    best_predictions = None

    evaluator = BinaryClassificationEvaluator(labelCol=target_column, rawPredictionCol="rawPrediction", metricName="areaUnderROC")

    for iteration in range(num_iterations):
        print(f"Iteration {iteration + 1} of {num_iterations}")

        
        assembler = VectorAssembler(inputCols=remaining_features, outputCol="features")
        assembled_df = assembler.transform(df).select("features", target_column)

        
        train_df, test_df = assembled_df.randomSplit([0.7, 0.3], seed=42)

        
        rf = RandomForestClassifier(featuresCol="features", labelCol=target_column, numTrees=100)
        rf_model = rf.fit(train_df)

        
        importances = rf_model.featureImportances
        feature_importance_pairs = sorted(zip(remaining_features, importances), key=lambda x: x[1], reverse=True)

        # Evaluate the model on the test set
        predictions = rf_model.transform(test_df)
        accuracy = evaluator.evaluate(predictions)
        print(f"Accuracy with remaining features: {accuracy}")

        # If current accuracy is better than the best, update the best accuracy, features, and predictions
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_features = remaining_features
            best_predictions = predictions

        # Keep all but the least important features based on the step size
        remaining_features = [x[0] for x in feature_importance_pairs[:-step_size]]

        # Stop early if fewer features remain than the step size
        if len(remaining_features) <= step_size:
            break

    # Compute the confusion matrix for the final selected features
    prediction_and_labels = best_predictions.select("prediction", target_column).rdd.map(lambda row: (float(row[0]), float(row[1])))
    metrics = MulticlassMetrics(prediction_and_labels)

    
    confusion_matrix = metrics.confusionMatrix().toArray()
    print("Confusion Matrix:")
    print(confusion_matrix)

    
    true_positives = confusion_matrix[1, 1]
    false_positives = confusion_matrix[0, 1]
    false_negatives = confusion_matrix[1, 0]
    true_negatives = confusion_matrix[0, 0]

    print(f"True Positives: {true_positives}")
    print(f"False Positives: {false_positives}")
    print(f"False Negatives: {false_negatives}")
    print(f"True Negatives: {true_negatives}")

    # Calculate precision, recall, and accuracy
    precision = metrics.precision(1.0)  # Assuming binary classification with positive class = 1.0
    recall = metrics.recall(1.0)
    final_accuracy = best_accuracy

    print(f"Final Accuracy: {final_accuracy}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")

    return best_features

# %%
# Perform RFECV with step size and metrics
selected_features = rfecv_with_step_size_and_metrics(df, target_column, initial_features, num_iterations=400, step_size=5)
# Out:
# Iteration 1 of 400
# Accuracy with remaining features: 0.5988898026315789
# Iteration 2 of 400
# Accuracy with remaining features: 0.5732230392156863
# Iteration 3 of 400
# Accuracy with remaining features: 0.5999180999181
# Iteration 4 of 400
# Accuracy with remaining features: 0.6335995085995086
# Iteration 5 of 400
# Accuracy with remaining features: 0.6183456183456184
# Iteration 6 of 400
# Accuracy with remaining features: 0.6060049019607843
# Iteration 7 of 400
# Accuracy with remaining features: 0.5083673469387753
# Iteration 8 of 400
# Accuracy with remaining features: 0.6029802000408246
# Iteration 9 of 400
# Accuracy with remaining features: 0.5395918367346938
# Iteration 10 of 400
# Accuracy with remaining features: 0.6072377836843181
# Iteration 11 of 400
# Accuracy with remaining features: 0.5692052293006848
# Iteration 12 of 400
# Accuracy with remaining features: 0.6215213358070499
# Iteration 13 of 400
# Accuracy with remaining features: 0.5899163094509083
# Iteration 14 of 400
# Accuracy with remaining features: 0.5861224489795916
# Iteration 15 of 400
# Accuracy with remaining features: 0.6212214052287581
# Iteration 16 of 400
# Accuracy with remaining features: 0.6002083333333335
# Iteration 17 of 400
# Accuracy with remaining features: 0.572480065426293
# Iteration 18 of 400
# Accuracy with remaining features: 0.5627679118187385
# Iteration 19 of 400
# Accuracy with remaining features: 0.5983438969535883
# Iteration 20 of 400
# Accuracy with remaining features: 0.6547959183673467
# Iteration 21 of 400
# Accuracy with remaining features: 0.5896381578947371
# Iteration 22 of 400
# Accuracy with remaining features: 0.6119281045751634
# Iteration 23 of 400
# Accuracy with remaining features: 0.5960988562091504
# Iteration 24 of 400
# Accuracy with remaining features: 0.5757761437908497
# Iteration 25 of 400
# Accuracy with remaining features: 0.5664414414414414
# Iteration 26 of 400
# Accuracy with remaining features: 0.6103046411776734
# Iteration 27 of 400
# Accuracy with remaining features: 0.5953061224489795
# Iteration 28 of 400
# Accuracy with remaining features: 0.6322051282051283
# Iteration 29 of 400
# Accuracy with remaining features: 0.5526530612244898
# Iteration 30 of 400
# Accuracy with remaining features: 0.5142886303327211
# Iteration 31 of 400
# Accuracy with remaining features: 0.6038602941176471
# Iteration 32 of 400
# Accuracy with remaining features: 0.5436117936117936
# Iteration 33 of 400
# Accuracy with remaining features: 0.6398026315789471
# Iteration 34 of 400
# Accuracy with remaining features: 0.5803717320261439
# Iteration 35 of 400
# Accuracy with remaining features: 0.6395016339869282
# Iteration 36 of 400
# Accuracy with remaining features: 0.54170926190963
# Iteration 37 of 400
# Accuracy with remaining features: 0.6197096708239623
# Iteration 38 of 400
# Accuracy with remaining features: 0.7227083333333335
# Iteration 39 of 400
# Accuracy with remaining features: 0.4863523573200993
# Iteration 40 of 400
# Accuracy with remaining features: 0.5409193980622552
# Iteration 41 of 400
# Accuracy with remaining features: 0.6454248366013073
# Iteration 42 of 400
# Accuracy with remaining features: 0.5835375816993464
# Iteration 43 of 400
# Accuracy with remaining features: 0.6377035662749948
# Iteration 44 of 400
# Accuracy with remaining features: 0.5943141730649513
# Iteration 45 of 400
# Accuracy with remaining features: 0.6515213815789472
# Iteration 46 of 400
# Accuracy with remaining features: 0.576986926748288
# Iteration 47 of 400
# Accuracy with remaining features: 0.6825396825396823
# Iteration 48 of 400
# Accuracy with remaining features: 0.6172902960526317
# Iteration 49 of 400
# Accuracy with remaining features: 0.6119356833642547
# Iteration 50 of 400
# Accuracy with remaining features: 0.563623366013072
# Iteration 51 of 400
# Accuracy with remaining features: 0.5514583333333333
# Iteration 52 of 400
# Accuracy with remaining features: 0.5754166666666666
# Iteration 53 of 400
# Accuracy with remaining features: 0.644815501958359
# Iteration 54 of 400
# Accuracy with remaining features: 0.5336734693877552
# Iteration 55 of 400
# Accuracy with remaining features: 0.6397223923249643
# Iteration 56 of 400
# Accuracy with remaining features: 0.5543988569095734
# Iteration 57 of 400
# Accuracy with remaining features: 0.5816326530612245
# Iteration 58 of 400
# Accuracy with remaining features: 0.6356907894736841
# Iteration 59 of 400
# Accuracy with remaining features: 0.5287262318544266
# Iteration 60 of 400
# Accuracy with remaining features: 0.6255118755118756
# Iteration 61 of 400
# Accuracy with remaining features: 0.6136363636363636
# Iteration 62 of 400
# Accuracy with remaining features: 0.5434782608695653
# Iteration 63 of 400
# Accuracy with remaining features: 0.58
# Iteration 64 of 400
# Accuracy with remaining features: 0.6547692307692307
# Iteration 65 of 400
# Accuracy with remaining features: 0.6616326530612243
# Iteration 66 of 400
# Accuracy with remaining features: 0.5871119281045751
# Iteration 67 of 400
# Accuracy with remaining features: 0.5641025641025641
# Iteration 68 of 400
# Accuracy with remaining features: 0.6081025641025641
# Iteration 69 of 400
# Accuracy with remaining features: 0.6403598446125537
# Iteration 70 of 400
# Accuracy with remaining features: 0.6697162828947368
# Iteration 71 of 400
# Accuracy with remaining features: 0.6173708920187795
# Iteration 72 of 400
# Accuracy with remaining features: 0.5859950859950862
# Iteration 73 of 400
# Accuracy with remaining features: 0.5431869717584002
# Iteration 74 of 400
# Accuracy with remaining features: 0.6031746031746033
# Iteration 75 of 400
# Accuracy with remaining features: 0.5976562499999999
# Iteration 76 of 400
# Accuracy with remaining features: 0.6692023026315789
# Iteration 77 of 400
# Accuracy with remaining features: 0.6424044162747904
# Iteration 78 of 400
# Accuracy with remaining features: 0.5875307125307124
# Iteration 79 of 400
# Accuracy with remaining features: 0.5124591503267975
# Iteration 80 of 400
# Accuracy with remaining features: 0.6250259389914921
# Iteration 81 of 400
# Accuracy with remaining features: 0.5454358974358975
# Iteration 82 of 400
# Accuracy with remaining features: 0.5889795918367347
# Iteration 83 of 400
# Accuracy with remaining features: 0.6099508599508598
# Iteration 84 of 400
# Accuracy with remaining features: 0.6527179487179487
# Iteration 85 of 400
# Accuracy with remaining features: 0.5450422593279737
# Iteration 86 of 400
# Accuracy with remaining features: 0.5583673469387755
# Iteration 87 of 400
# Accuracy with remaining features: 0.6427108927108925
# Iteration 88 of 400
# Accuracy with remaining features: 0.5882232672255163
# Iteration 89 of 400
# Accuracy with remaining features: 0.6563275434243179
# Iteration 90 of 400
# Accuracy with remaining features: 0.611655439885691
# Iteration 91 of 400
# Accuracy with remaining features: 0.6285416666666664
# Iteration 92 of 400
# Accuracy with remaining features: 0.547520232413364
# Iteration 93 of 400
# Accuracy with remaining features: 0.6405228758169935
# Iteration 94 of 400
# Accuracy with remaining features: 0.5816106804478899
# Iteration 95 of 400
# Accuracy with remaining features: 0.6167076167076166
# Iteration 96 of 400
# Accuracy with remaining features: 0.6184479934479934
# Iteration 97 of 400
# Accuracy with remaining features: 0.591932841932842
# Iteration 98 of 400
# Accuracy with remaining features: 0.6090256410256412
# Iteration 99 of 400
# Accuracy with remaining features: 0.5803225147989386
# Iteration 100 of 400
# Accuracy with remaining features: 0.5708101422387137
# Iteration 101 of 400
# Accuracy with remaining features: 0.5428512139448017
# Iteration 102 of 400
# Accuracy with remaining features: 0.641641025641026
# Iteration 103 of 400
# Accuracy with remaining features: 0.6072836688109566
# Iteration 104 of 400
# Accuracy with remaining features: 0.6552220394736841
# Iteration 105 of 400
# Accuracy with remaining features: 0.6232876712328766
# Iteration 106 of 400
# Accuracy with remaining features: 0.5921079533837661
# Iteration 107 of 400
# Accuracy with remaining features: 0.6026374974442854
# Iteration 108 of 400
# Accuracy with remaining features: 0.6212121212121212
# Iteration 109 of 400
# Accuracy with remaining features: 0.6212214052287581
# Iteration 110 of 400
# Accuracy with remaining features: 0.5655384615384617
# Iteration 111 of 400
# Accuracy with remaining features: 0.6566339066339066
# Iteration 112 of 400
# Accuracy with remaining features: 0.6709261909629931
# Iteration 113 of 400
# Accuracy with remaining features: 0.6198937908496732
# Iteration 114 of 400
# Accuracy with remaining features: 0.6541769041769041
# Iteration 115 of 400
# Accuracy with remaining features: 0.6998355263157893
# Iteration 116 of 400
# Accuracy with remaining features: 0.6310204081632651
# Iteration 117 of 400
# Accuracy with remaining features: 0.6655102040816326
# Iteration 118 of 400
# Accuracy with remaining features: 0.5846011513157894
# Iteration 119 of 400
# Accuracy with remaining features: 0.6633986928104575
# Iteration 120 of 400
# Accuracy with remaining features: 0.6705569205569206
# Iteration 121 of 400
# Accuracy with remaining features: 0.6090686274509804
# Iteration 122 of 400
# Accuracy with remaining features: 0.7159377628259043
# Iteration 123 of 400
# Accuracy with remaining features: 0.5979487179487181
# Iteration 124 of 400
# Accuracy with remaining features: 0.5809111523397236
# Iteration 125 of 400
# Accuracy with remaining features: 0.5889507318078745
# Iteration 126 of 400
# Accuracy with remaining features: 0.6830024813895784
# Iteration 127 of 400
# Accuracy with remaining features: 0.6656410256410257
# Iteration 128 of 400
# Accuracy with remaining features: 0.5374276261373035
# Iteration 129 of 400
# Accuracy with remaining features: 0.6369533375183092
# Iteration 130 of 400
# Accuracy with remaining features: 0.6258223684210527
# Iteration 131 of 400
# Accuracy with remaining features: 0.6914062500000001
# Iteration 132 of 400
# Accuracy with remaining features: 0.6363357843137255
# Iteration 133 of 400
# Accuracy with remaining features: 0.6232596232596233
# Iteration 134 of 400
# Accuracy with remaining features: 0.6453726453726455
# Iteration 135 of 400
# Accuracy with remaining features: 0.7160089961153139
# Iteration 136 of 400
# Accuracy with remaining features: 0.6732632446918159
# Iteration 137 of 400
# Accuracy with remaining features: 0.6117936117936119
# Iteration 138 of 400
# Accuracy with remaining features: 0.59906045751634
# Iteration 139 of 400
# Accuracy with remaining features: 0.6519697897530109
# Iteration 140 of 400
# Accuracy with remaining features: 0.6404586404586406
# Iteration 141 of 400
# Accuracy with remaining features: 0.6695384615384616
# Iteration 142 of 400
# Accuracy with remaining features: 0.6487038171055319
# Iteration 143 of 400
# Accuracy with remaining features: 0.580220453153705
# Iteration 144 of 400
# Accuracy with remaining features: 0.6405388854868341
# Iteration 145 of 400
# Accuracy with remaining features: 0.5751633986928105
# Iteration 146 of 400
# Accuracy with remaining features: 0.6614358974358976
# Iteration 147 of 400
# Accuracy with remaining features: 0.5894607843137255
# Iteration 148 of 400
# Accuracy with remaining features: 0.6671572750210263
# Iteration 149 of 400
# Accuracy with remaining features: 0.5968137254901961
# Iteration 150 of 400
# Accuracy with remaining features: 0.5944897959183673
# Iteration 151 of 400
# Accuracy with remaining features: 0.7063686466625838
# Iteration 152 of 400
# Accuracy with remaining features: 0.6535384615384616
# Iteration 153 of 400
# Accuracy with remaining features: 0.63440527726242
# Iteration 154 of 400
# Accuracy with remaining features: 0.6965624999999998
# Iteration 155 of 400
# Accuracy with remaining features: 0.6705473856209151
# Iteration 156 of 400
# Accuracy with remaining features: 0.6233660130718954
# Iteration 157 of 400
# Accuracy with remaining features: 0.6274790431404621
# Iteration 158 of 400
# Accuracy with remaining features: 0.5685128205128206
# Iteration 159 of 400
# Accuracy with remaining features: 0.685948717948718
# Iteration 160 of 400
# Accuracy with remaining features: 0.623798814148436
# Iteration 161 of 400
# Accuracy with remaining features: 0.68424317617866
# Iteration 162 of 400
# Accuracy with remaining features: 0.6349206349206349
# Iteration 163 of 400
# Accuracy with remaining features: 0.6451645880188098
# Iteration 164 of 400
# Accuracy with remaining features: 0.6529904062053482
# Iteration 165 of 400
# Accuracy with remaining features: 0.7382653061224489
# Iteration 166 of 400
# Accuracy with remaining features: 0.6929053363320384
# Iteration 167 of 400
# Accuracy with remaining features: 0.634511993382961
# Iteration 168 of 400
# Accuracy with remaining features: 0.6025326797385621
# Iteration 169 of 400
# Accuracy with remaining features: 0.7151898734177216
# Iteration 170 of 400
# Accuracy with remaining features: 0.6627377998345743
# Iteration 171 of 400
# Accuracy with remaining features: 0.6068050986842105
# Iteration 172 of 400
# Accuracy with remaining features: 0.6105327617881199
# Iteration 173 of 400
# Accuracy with remaining features: 0.6927008791658148
# Iteration 174 of 400
# Accuracy with remaining features: 0.6759882253994954
# Iteration 175 of 400
# Accuracy with remaining features: 0.6590393733250877
# Iteration 176 of 400
# Accuracy with remaining features: 0.5767882910740054
# Iteration 177 of 400
# Accuracy with remaining features: 0.6565677526457772
# Iteration 178 of 400
# Accuracy with remaining features: 0.647479077362727
# Iteration 179 of 400
# Accuracy with remaining features: 0.6560457516339869
# Iteration 180 of 400
# Accuracy with remaining features: 0.7623355263157893
# Iteration 181 of 400
# Accuracy with remaining features: 0.6160204081632653
# Iteration 182 of 400
# Accuracy with remaining features: 0.7265641025641029
# Iteration 183 of 400
# Accuracy with remaining features: 0.6471794871794873
# Iteration 184 of 400
# Accuracy with remaining features: 0.6681985294117647
# Iteration 185 of 400
# Accuracy with remaining features: 0.6515027601717439
# Iteration 186 of 400
# Accuracy with remaining features: 0.6245888157894736
# Iteration 187 of 400
# Accuracy with remaining features: 0.6338028169014083
# Iteration 188 of 400
# Accuracy with remaining features: 0.6184935701163503
# Iteration 189 of 400
# Accuracy with remaining features: 0.7341034553261091
# Iteration 190 of 400
# Accuracy with remaining features: 0.76747311827957
# Iteration 191 of 400
# Accuracy with remaining features: 0.6831825657894737
# Iteration 192 of 400
# Accuracy with remaining features: 0.5625644197072768
# Iteration 193 of 400
# Accuracy with remaining features: 0.6516049887548558
# Iteration 194 of 400
# Accuracy with remaining features: 0.6701367626046132
# Iteration 195 of 400
# Accuracy with remaining features: 0.6278832414778526
# Iteration 196 of 400
# Accuracy with remaining features: 0.6207319566550807
# Iteration 197 of 400
# Accuracy with remaining features: 0.6796683046683047
# Iteration 198 of 400
# Accuracy with remaining features: 0.6724565756823822
# Iteration 199 of 400
# Accuracy with remaining features: 0.7205552153500714
# Iteration 200 of 400
# Accuracy with remaining features: 0.7353061224489794
# Iteration 201 of 400
# Accuracy with remaining features: 0.7019657577679137
# Iteration 202 of 400
# Accuracy with remaining features: 0.7146875000000001
# Iteration 203 of 400
# Accuracy with remaining features: 0.6812307692307693
# Iteration 204 of 400
# Accuracy with remaining features: 0.6812244897959182
# Iteration 205 of 400
# Accuracy with remaining features: 0.7618755118755121
# Iteration 206 of 400
# Accuracy with remaining features: 0.6695384615384619
# Iteration 207 of 400
# Accuracy with remaining features: 0.7116709732988804
# Iteration 208 of 400
# Accuracy with remaining features: 0.7138480392156863
# Iteration 209 of 400
# Accuracy with remaining features: 0.6914414414414414
# Iteration 210 of 400
# Accuracy with remaining features: 0.694019187589304
# Iteration 211 of 400
# Accuracy with remaining features: 0.603557554692292
# Iteration 212 of 400
# Accuracy with remaining features: 0.6548202614379085
# Iteration 213 of 400
# Accuracy with remaining features: 0.7091596810468206
# Iteration 214 of 400
# Accuracy with remaining features: 0.6712582236842104
# Iteration 215 of 400
# Accuracy with remaining features: 0.7722119150690577
# Iteration 216 of 400
# Accuracy with remaining features: 0.6130648129216929
# Iteration 217 of 400
# Accuracy with remaining features: 0.6900330851943755
# Iteration 218 of 400
# Accuracy with remaining features: 0.6661059714045416
# Iteration 219 of 400
# Accuracy with remaining features: 0.6386158886158886
# Iteration 220 of 400
# Accuracy with remaining features: 0.6491515027601715
# Iteration 221 of 400
# Accuracy with remaining features: 0.6810002092487968
# Iteration 222 of 400
# Accuracy with remaining features: 0.6350327600327601
# Iteration 223 of 400
# Accuracy with remaining features: 0.6691403834260976
# Iteration 224 of 400
# Accuracy with remaining features: 0.6600954554886908
# Iteration 225 of 400
# Accuracy with remaining features: 0.7360457984052341
# Iteration 226 of 400
# Accuracy with remaining features: 0.7006122448979591
# Iteration 227 of 400
# Accuracy with remaining features: 0.7187691678593334
# Iteration 228 of 400
# Accuracy with remaining features: 0.6723856209150326
# Iteration 229 of 400
# Accuracy with remaining features: 0.7011282051282051
# Iteration 230 of 400
# Accuracy with remaining features: 0.7247753267973858
# Iteration 231 of 400
# Accuracy with remaining features: 0.6540032679738562
# Iteration 232 of 400
# Accuracy with remaining features: 0.7317772317772319
# Iteration 233 of 400
# Accuracy with remaining features: 0.644653445103251
# Iteration 234 of 400
# Accuracy with remaining features: 0.6857638888888888
# Iteration 235 of 400
# Accuracy with remaining features: 0.7243076923076925
# Iteration 236 of 400
# Accuracy with remaining features: 0.6633612758127173
# Iteration 237 of 400
# Accuracy with remaining features: 0.6883037354562155
# Iteration 238 of 400
# Accuracy with remaining features: 0.7287581699346405
# Iteration 239 of 400
# Accuracy with remaining features: 0.6579055864770149
# Iteration 240 of 400
# Accuracy with remaining features: 0.6743100228263127
# Iteration 241 of 400
# Accuracy with remaining features: 0.7463768115942029
# Iteration 242 of 400
# Accuracy with remaining features: 0.6266447368421052
# Iteration 243 of 400
# Accuracy with remaining features: 0.7076891362605648
# Iteration 244 of 400
# Accuracy with remaining features: 0.7430087773014902
# Iteration 245 of 400
# Accuracy with remaining features: 0.7532149418248621
# Iteration 246 of 400
# Accuracy with remaining features: 0.7747499489691776
# Iteration 247 of 400
# Accuracy with remaining features: 0.6535947712418301
# Iteration 248 of 400
# Accuracy with remaining features: 0.6921025641025641
# Iteration 249 of 400
# Accuracy with remaining features: 0.6877559377559378
# Iteration 250 of 400
# Accuracy with remaining features: 0.7094304960195956
# Iteration 251 of 400
# Accuracy with remaining features: 0.6840277777777779
# Iteration 252 of 400
# Accuracy with remaining features: 0.6948198198198198
# Iteration 253 of 400
# Accuracy with remaining features: 0.7232088181261483
# Iteration 254 of 400
# Accuracy with remaining features: 0.6906224406224405
# Iteration 255 of 400
# Accuracy with remaining features: 0.7366591699039052
# Iteration 256 of 400
# Accuracy with remaining features: 0.6754493464052288
# Iteration 257 of 400
# Accuracy with remaining features: 0.6479166666666666
# Iteration 258 of 400
# Accuracy with remaining features: 0.7212244897959182
# Iteration 259 of 400
# Accuracy with remaining features: 0.8057142857142855
# Iteration 260 of 400
# Accuracy with remaining features: 0.7378173628173628
# Iteration 261 of 400
# Accuracy with remaining features: 0.8174019607843138
# Iteration 262 of 400
# Accuracy with remaining features: 0.6547692307692308
# Iteration 263 of 400
# Accuracy with remaining features: 0.6973684210526316
# Iteration 264 of 400
# Accuracy with remaining features: 0.7473469387755102
# Iteration 265 of 400
# Accuracy with remaining features: 0.7181538461538464
# Iteration 266 of 400
# Accuracy with remaining features: 0.6486458333333334
# Iteration 267 of 400
# Accuracy with remaining features: 0.724468954248366
# Iteration 268 of 400
# Accuracy with remaining features: 0.799836434267021
# Iteration 269 of 400
# Accuracy with remaining features: 0.7462564102564104
# Iteration 270 of 400
# Accuracy with remaining features: 0.6842159067675321
# Iteration 271 of 400
# Accuracy with remaining features: 0.6469743589743591
# Iteration 272 of 400
# Accuracy with remaining features: 0.7215758318024086
# Iteration 273 of 400
# Accuracy with remaining features: 0.6828834484201715
# Iteration 274 of 400
# Accuracy with remaining features: 0.7063688999172874
# Iteration 275 of 400
# Accuracy with remaining features: 0.794929462277653
# Iteration 276 of 400
# Accuracy with remaining features: 0.6116912366912367
# Iteration 277 of 400
# Accuracy with remaining features: 0.7397875816993463
# Iteration 278 of 400
# Accuracy with remaining features: 0.7167179487179489
# Iteration 279 of 400
# Accuracy with remaining features: 0.7797948717948721
# Iteration 280 of 400
# Accuracy with remaining features: 0.7429743589743589
# Iteration 281 of 400
# Accuracy with remaining features: 0.7191584967320261
# Iteration 282 of 400
# Accuracy with remaining features: 0.7721025641025641
# Iteration 283 of 400
# Accuracy with remaining features: 0.6318591318591319
# Iteration 284 of 400
# Accuracy with remaining features: 0.6943423202614379
# Iteration 285 of 400
# Accuracy with remaining features: 0.7474468954248366
# Iteration 286 of 400
# Accuracy with remaining features: 0.7685241886099207
# Iteration 287 of 400
# Accuracy with remaining features: 0.772030259660601
# Iteration 288 of 400
# Accuracy with remaining features: 0.6959292763157893
# Iteration 289 of 400
# Accuracy with remaining features: 0.7321867321867322
# Iteration 290 of 400
# Accuracy with remaining features: 0.7577819006390434
# Iteration 291 of 400
# Accuracy with remaining features: 0.7290131040131044
# Iteration 292 of 400
# Accuracy with remaining features: 0.7769372316499695
# Iteration 293 of 400
# Accuracy with remaining features: 0.7115737905695039
# Iteration 294 of 400
# Accuracy with remaining features: 0.7640334762196366
# Iteration 295 of 400
# Accuracy with remaining features: 0.7429693961952027
# Iteration 296 of 400
# Accuracy with remaining features: 0.717849110611327
# Iteration 297 of 400
# Accuracy with remaining features: 0.8088205128205131
# Iteration 298 of 400
# Accuracy with remaining features: 0.7922715191167446
# Iteration 299 of 400
# Accuracy with remaining features: 0.8065641025641029
# Iteration 300 of 400
# Accuracy with remaining features: 0.801266339869281
# Iteration 301 of 400
# Accuracy with remaining features: 0.7461091512761979
# Iteration 302 of 400
# Accuracy with remaining features: 0.7897215397215397
# Iteration 303 of 400
# Accuracy with remaining features: 0.7616694701429775
# Iteration 304 of 400
# Accuracy with remaining features: 0.7087179487179488
# Iteration 305 of 400
# Accuracy with remaining features: 0.7253521126760563
# Iteration 306 of 400
# Accuracy with remaining features: 0.7701901451645885
# Iteration 307 of 400
# Accuracy with remaining features: 0.7659313725490198
# Iteration 308 of 400
# Accuracy with remaining features: 0.7523984486629925
# Iteration 309 of 400
# Accuracy with remaining features: 0.7375107665805342
# Iteration 310 of 400
# Accuracy with remaining features: 0.7350898692810456
# Iteration 311 of 400
# Accuracy with remaining features: 0.7772671568627451
# Iteration 312 of 400
# Accuracy with remaining features: 0.71007371007371
# Iteration 313 of 400
# Accuracy with remaining features: 0.7627692307692311
# Iteration 314 of 400
# Accuracy with remaining features: 0.7428337428337428
# Iteration 315 of 400
# Accuracy with remaining features: 0.7465753424657534
# Iteration 316 of 400
# Accuracy with remaining features: 0.7819695723684209
# Iteration 317 of 400
# Accuracy with remaining features: 0.7889095031952174
# Iteration 318 of 400
# Accuracy with remaining features: 0.7593386405388854
# Iteration 319 of 400
# Accuracy with remaining features: 0.7201025641025643
# Iteration 320 of 400
# Accuracy with remaining features: 0.7570932843437436
# Iteration 321 of 400
# Accuracy with remaining features: 0.7642608873441015
# Iteration 322 of 400
# Accuracy with remaining features: 0.826938775510204
# Iteration 323 of 400
# Accuracy with remaining features: 0.7903589743589745
# Iteration 324 of 400
# Accuracy with remaining features: 0.8372140522875817
# Iteration 325 of 400
# Accuracy with remaining features: 0.7003480753480753
# Iteration 326 of 400
# Accuracy with remaining features: 0.8144963144963145
# Iteration 327 of 400
# Accuracy with remaining features: 0.7694358974358976
# Iteration 328 of 400
# Accuracy with remaining features: 0.810752467105263
# Iteration 329 of 400
# Accuracy with remaining features: 0.7553881565180999
# Iteration 330 of 400
# Accuracy with remaining features: 0.8302696078431373
# Iteration 331 of 400
# Accuracy with remaining features: 0.7264093137254902
# Iteration 332 of 400
# Accuracy with remaining features: 0.7363430220573076
# Iteration 333 of 400
# Accuracy with remaining features: 0.8490256410256409
# Iteration 334 of 400
# Accuracy with remaining features: 0.8390922101819669
# Iteration 335 of 400
# Accuracy with remaining features: 0.7803970223325065
# Iteration 336 of 400
# Accuracy with remaining features: 0.7311224489795918
# Iteration 337 of 400
# Accuracy with remaining features: 0.739692307692308
# Iteration 338 of 400
# Accuracy with remaining features: 0.7683823529411766
# Iteration 339 of 400
# Accuracy with remaining features: 0.8501838235294117
# Iteration 340 of 400
# Accuracy with remaining features: 0.7364102564102565
# Iteration 341 of 400
# Accuracy with remaining features: 0.7709750566893424
# Iteration 342 of 400
# Accuracy with remaining features: 0.75
# Iteration 343 of 400
# Accuracy with remaining features: 0.7512883941455368
# Iteration 344 of 400
# Accuracy with remaining features: 0.7308717948717951
# Iteration 345 of 400
# Accuracy with remaining features: 0.7734885620915033
# Iteration 346 of 400
# Accuracy with remaining features: 0.8295641447368419
# Iteration 347 of 400
# Accuracy with remaining features: 0.7719942845478671
# Iteration 348 of 400
# Accuracy with remaining features: 0.8151707217337968
# Iteration 349 of 400
# Accuracy with remaining features: 0.7873035313329249
# Iteration 350 of 400
# Accuracy with remaining features: 0.7826576576576578
# Iteration 351 of 400
# Accuracy with remaining features: 0.808763308763309
# Iteration 352 of 400
# Accuracy with remaining features: 0.800558312655087
# Iteration 353 of 400
# Accuracy with remaining features: 0.7904314046207319
# Iteration 354 of 400
# Accuracy with remaining features: 0.8001429738562092
# Iteration 355 of 400
# Accuracy with remaining features: 0.7605459057071962
# Iteration 356 of 400
# Accuracy with remaining features: 0.7742857142857141
# Iteration 357 of 400
# Accuracy with remaining features: 0.7861265718408574
# Iteration 358 of 400
# Accuracy with remaining features: 0.841475984333127
# Iteration 359 of 400
# Accuracy with remaining features: 0.7789011437908497
# Iteration 360 of 400
# Accuracy with remaining features: 0.8589583333333329
# Iteration 361 of 400
# Accuracy with remaining features: 0.8364045864045863
# Iteration 362 of 400
# Accuracy with remaining features: 0.7841025641025643
# Iteration 363 of 400
# Accuracy with remaining features: 0.8216911764705883
# Iteration 364 of 400
# Accuracy with remaining features: 0.7605128205128205
# Iteration 365 of 400
# Accuracy with remaining features: 0.7941176470588236
# Iteration 366 of 400
# Accuracy with remaining features: 0.8428571428571427
# Iteration 367 of 400
# Accuracy with remaining features: 0.8473846153846154
# Iteration 368 of 400
# Accuracy with remaining features: 0.844853096596914
# Iteration 369 of 400
# Accuracy with remaining features: 0.8506666666666667
# Iteration 370 of 400
# Accuracy with remaining features: 0.7602739726027394
# Iteration 371 of 400
# Accuracy with remaining features: 0.8614718614718614
# Iteration 372 of 400
# Accuracy with remaining features: 0.7418099918099921
# Iteration 373 of 400
# Accuracy with remaining features: 0.8256122448979591
# Iteration 374 of 400
# Accuracy with remaining features: 0.7686887254901961
# Iteration 375 of 400
# Accuracy with remaining features: 0.8805878750765462
# Iteration 376 of 400
# Accuracy with remaining features: 0.8128194643222245
# Iteration 377 of 400
# Accuracy with remaining features: 0.7697381983096266
# Iteration 378 of 400
# Accuracy with remaining features: 0.8378654671846254
# Iteration 379 of 400
# Accuracy with remaining features: 0.7731367731367732
# Iteration 380 of 400
# Accuracy with remaining features: 0.7865953947368419
# Iteration 381 of 400
# Accuracy with remaining features: 0.823794871794872
# Iteration 382 of 400
# Accuracy with remaining features: 0.8093877551020408
# Iteration 383 of 400
# Accuracy with remaining features: 0.8522796974033944
# Iteration 384 of 400
# Accuracy with remaining features: 0.8244416873449137
# Iteration 385 of 400
# Accuracy with remaining features: 0.7657190288441582
# Iteration 386 of 400
# Accuracy with remaining features: 0.8282271241830066
# Iteration 387 of 400
# Accuracy with remaining features: 0.8191836734693876
# Iteration 388 of 400
# Accuracy with remaining features: 0.8249845392702535
# Iteration 389 of 400
# Accuracy with remaining features: 0.8175510204081631
# Iteration 390 of 400
# Accuracy with remaining features: 0.7446546052631577
# Iteration 391 of 400
# Accuracy with remaining features: 0.8187295751633987
# Iteration 392 of 400
# Accuracy with remaining features: 0.8073251711973436
# Iteration 393 of 400
# Accuracy with remaining features: 0.7892886683209267
# Iteration 394 of 400
# Accuracy with remaining features: 0.7874055929781589
# Iteration 395 of 400
# Accuracy with remaining features: 0.8244897959183672
# Iteration 396 of 400
# Accuracy with remaining features: 0.7728480883254957
# Iteration 397 of 400
# Accuracy with remaining features: 0.7313737497448459
# Iteration 398 of 400
# Accuracy with remaining features: 0.7953546767106088
# Iteration 399 of 400
# Accuracy with remaining features: 0.7223478618421052
# Confusion Matrix:
# [[51. 18.]
#  [15. 56.]]
# True Positives: 56.0
# False Positives: 18.0
# False Negatives: 15.0
# True Negatives: 51.0
# Final Accuracy: 0.8805878750765462
# Precision: 0.7567567567567568
# Recall: 0.7887323943661971

# %%
def find_top_features(df, target_column, selected_features, top_n=10):
    
    assembler = VectorAssembler(inputCols=selected_features, outputCol="features")
    assembled_df = assembler.transform(df).select("features", target_column)
    
    train_df, test_df = assembled_df.randomSplit([0.7, 0.3], seed=42)
    
    rf = RandomForestClassifier(featuresCol="features", labelCol=target_column, numTrees=100)
    rf_model = rf.fit(train_df)
    
    importances = rf_model.featureImportances
    feature_importance_pairs = list(zip(selected_features, importances))

    # Sort pairs by importance scores in descending order
    sorted_features = sorted(feature_importance_pairs, key=lambda x: x[1], reverse=True)

    # Retrieve the top N features
    top_features = sorted_features[:top_n]

    
    top_features_df = pd.DataFrame(top_features, columns=["Feature", "Importance"])
    return top_features_df

# %%
top_n = 10 
top_features_df = find_top_features(df, target_column, selected_features, top_n)

# %%
print("Top Features:")
print(top_features_df)
# Out:
# Top Features:
#         Feature  Importance
# 0  rs11576569_A    0.060714
# 1   rs3116102_A    0.019532
# 2   rs4374108_A    0.016708
# 3   rs4661540_A    0.016139
# 4   rs3935665_G    0.015611
# 5   rs2447232_G    0.015538
# 6   rs9496698_G    0.014218
# 7   rs2029253_G    0.014163
# 8   rs1413529_G    0.013794
# 9   rs1938426_G    0.013759

# %%
print("Number of selected features : " ,len(selected_features) )
# Out:
# Number of selected features :  130
